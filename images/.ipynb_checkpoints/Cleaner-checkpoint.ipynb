# %% [markdown]
# Base files

# %%
with open('export_733.txt', 'r') as oldfile, open('base_export_antman.txt','w') as cleaned:
    for row in oldfile:
        if "png|ball|{" in row:
            print(row)
            cleaned.write(row)

# %% [markdown]
# AI ball exports

# %%
with open('export_ball_351.txt', 'r') as oldfile, open('export_ball_hulk.txt','w') as cleaned:
    for row in oldfile:
        if "png|not_in_image" not in row:
            print(row)
            cleaned.write(row)
# Out:
# Export of Imageset Testgame_22_12_17_Hulk (ball annotations in bounding boxes)
#
# [team|NaoDevils]
#
# [set|Testgame_22_12_17_Hulk]
#
# [format: "label::annotation_type|filename|img_width|img_height|x1|y1|x2|y2|center_x|center_y|width|height"]
#
#
#
#
#
# label::ball|26_01_2018__19_38_28_0866_upper.png|640|480|321|166|383|227|352.0|196.5|62|61
#
# label::ball|26_01_2018__19_38_28_0865_upper.png|640|480|321|173|379|232|350.0|202.5|58|59
#
# label::ball|26_01_2018__19_38_28_0864_upper.png|640|480|324|188|385|247|354.5|217.5|61|59
#
# label::ball|26_01_2018__19_38_28_0863_upper.png|640|480|317|185|377|246|347.0|215.5|60|61
#
# label::ball|26_01_2018__19_38_28_0862_upper.png|640|480|320|174|378|234|349.0|204.0|58|60
#
# label::ball|26_01_2018__19_38_28_0861_upper.png|640|480|329|179|385|236|357.0|207.5|56|57
#
# label::ball|26_01_2018__19_38_28_0860_upper.png|640|480|329|169|385|227|357.0|198.0|56|58
#
# ...
